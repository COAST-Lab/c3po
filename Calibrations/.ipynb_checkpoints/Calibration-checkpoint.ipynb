# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import os
import scipy
import matplotlib.cm as cm
from datetime import datetime
import seaborn as sns
import pytz
import matplotlib
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from sklearn import metrics
from sklearn.metrics import r2_score

# %% [markdown]
# Before loading in the conductivity data, ensure you have calculated the proper datetime based off of the time the C3PO was plugged into power, which was recorded in Notes.txt. Ensure to save these datetimes as a column. It is easy to do in excel, and you can use previous calibration csvs for an example.
#
# You'll also need to create a "step_pts_interp.csv" file in the working folder that "fills in" points from every step change from the step_pts.txt file for every 20 seconds. Again, use previous spreadsheets as an example if needed.
#
# Check your conductivity data beforehand and remove points that were taken while moving the probe from one solution to the other if needed (often appears as 0 or an erroneous value when you know the sensor was coming in or out of the solution at that time).

# %%
# USER INPUT 
filename = 'conductivity' #data from the calibration 
device = 'C3PO_6' 
folder = '2026_07_22_Calibration'

filepath = os.path.join(device, folder, filename+'.csv') 
cond = pd.read_csv(filepath, header = 0, parse_dates =[7], date_format='%yyyy-%m-%d %HH:%MM:%SS') 
cond.head()
#cond.tail()
# Out:
#    Real_Time  Temp_C  Cond_uScm-1  CellVoltage  StateofCharge  ErrorCode  \
# 0  946684805   22.27            0         0.84          99.24          0
# 1  946684823   22.40            0         0.05          97.82          0
# 2  946684843   22.40            0         0.05          96.39          0
# 3  946684862   22.40            0         0.05          94.81          0
# 4  946684882   22.40            0         0.05          93.23          0
#
#    Elapsed_sec             datetime
# 0            0  2026-07-22 13:35:10
# 1           18  2026-07-22 13:35:28
# 2           38  2026-07-22 13:35:48
# 3           57  2026-07-22 13:36:07
# 4           77  2026-07-22 13:36:27

# %%
filename = 'step_pts' #data from the calibration 
filepath = os.path.join(device, folder, filename+'.txt') 
steps = pd.read_csv(filepath, header = 0, parse_dates =['datetime'], date_format='%yyyy-%m-%d %HH:%MM:%SS') 
steps.tail()
# Out:
#    cond_uscm            datetime
# 1          0  2026-7-22 13:49:00
# 2      12880  2026-7-22 13:50:25
# 3      12880  2026-7-22 13:58:00
# 4      80000  2026-7-22 13:59:28
# 5      80000  2026-7-22 14:05:00

# %%
cond['datetime'] = pd.to_datetime(cond['datetime'])
steps['datetime']= pd.to_datetime(steps['datetime'])

# %%
#Plot raw points 
plt.rcParams.update({'font.size': 22})
fig, axs = plt.subplots(figsize = (14, 10))

axs.plot(cond["datetime"], cond["Cond_uScm-1"], label = "C3PO reading", color = "red")
axs.plot(steps["datetime"], steps["cond_uscm"], label = "Set point", marker = '*', color = "blue")
axs.set_ylabel('Conductivity (us/cm)')
axs.set_xlabel('Datetime')

plt.legend()

fig_fn = 'RawReadings'
fig_file = os.path.join(device, folder, 'Figures', device+fig_fn+'.png')
plt.savefig(fig_file, dpi = 200, transparent=False)

# %%
filename = 'step_pts_interp' 
filepath = os.path.join(device, folder, filename+'.csv') 
steps2 = pd.read_csv(filepath, header = 0, parse_dates =['datetime'], date_format='%yyyy-%m-%d %HH:%MM:%SS') 
steps2['datetime']= pd.to_datetime(steps2['datetime'])
steps2.head()
# Out:
#    cond_uscm            datetime
# 0          0 2026-07-22 13:43:30
# 44      80000 2026-07-22 14:00:08  946686302   23.06        78370
# 45      80000 2026-07-22 14:00:28  946686322   23.05        78470
# 46      80000 2026-07-22 14:00:48  946686343   23.04        78510
# 47      80000 2026-07-22 14:01:08  946686363   23.03        78530
# 48      80000 2026-07-22 14:01:28  946686382   23.03        78560
# 49      80000 2026-07-22 14:01:48  946686402   23.03        78570
# 50      80000 2026-07-22 14:02:08  946686422   23.02        78590
# 51      80000 2026-07-22 14:02:28  946686442   23.02        78590
# 52      80000 2026-07-22 14:02:48  946686463   23.02        78650
# 53      80000 2026-07-22 14:03:08  946686483   23.02        78680
# 54      80000 2026-07-22 14:03:28  946686502   23.01        78660
# 55      80000 2026-07-22 14:03:48  946686522   23.01        78680
# 56      80000 2026-07-22 14:04:08  946686542   23.01        78690
# 57      80000 2026-07-22 14:04:28  946686563   23.01        78690
# 58      80000 2026-07-22 14:04:48  946686583   23.00        78690
# 59      80000 2026-07-22 14:05:00  946686583   23.00        78690
#
#     CellVoltage  StateofCharge  ErrorCode  Elapsed_sec
# 0          0.05          62.53          0          497
# 1          0.05          61.06          0          518
# 2          0.05          59.79          0          538
# 3          0.05          58.53          0          558
# 4          0.05          56.95          0          577
# 5          0.05          55.36          0          597
# 6          0.05          54.10          0          618
# 7          0.05          52.70          0          638
# 8          0.05          51.16          0          658
# 9          0.05          49.62          0          677
# 10         0.05          48.09          0          697
# 11         0.05          46.91          0          718
# 12         0.05          45.28          0          738
# 13         0.05          44.05          0          758
# 14         0.05          42.41          0          777
# 15         0.05          41.19          0          797
# 16         0.05          39.75          0          818
# 17         0.05          39.75          0          818
# 18         0.05          32.55          0          918
# 19         0.05          30.83          0          938
# 20         0.05          29.54          0          958
# 21         0.05          28.25          0          977
# 22         0.05          26.54          0          997
# 23         0.05          25.25          0         1018
# 24         0.05          23.96          0         1038
# 25         0.05          22.67          0         1058
# 26         0.05          20.95          0         1077
# 27         0.05          19.57          0         1097
# 28         0.05          18.02          0         1118
# 29         0.05          16.73          0         1138
# 30         0.05          15.17          0         1158
# 31         0.05          13.88          0         1177
# 32         0.05          12.33          0         1197
# 33         0.05          11.03          0         1218
# 34         0.05           9.48          0         1238
# 35         0.05           8.21          0         1258
# 36         0.05           6.73          0         1277
# 37         0.05           5.40          0         1297
# 38         0.05           4.21          0         1317
# 39         0.05           2.94          0         1338
# 40         0.05           1.98          0         1358
# 41         0.05           1.98          0         1358
# 42         0.05           0.00          0         1458
# 43         0.05           0.00          0         1477
# 44         0.05           0.00          0         1497
# 45         0.05           0.00          0         1517
# 46         0.05           0.00          0         1538
# 47         0.05           0.00          0         1558
# 48         0.05           0.00          0         1577
# 49         0.05           0.00          0         1597
# 50         0.05           0.00          0         1617
# 51         0.05           0.00          0         1637
# 52         0.05           0.00          0         1658
# 53         0.05           0.00          0         1678
# 54         0.05           0.00          0         1697
# 55         0.05           0.00          0         1717
# 56         0.05           0.00          0         1737
# 57         0.05           0.00          0         1758
# 58         0.05           0.00          0         1778
# 59         0.05           0.00          0         1778

# %%
filename = 'merged' 
filepath = os.path.join(device, folder, filename+'.csv') 
mergedcleaned = pd.read_csv(filepath, header = 0, parse_dates =['datetime'], date_format='%yyyy-%m-%d %HH:%MM:%SS') 
mergedcleaned['datetime']= pd.to_datetime(mergedcleaned['datetime'])
mergedcleaned.head()
# Out:
#    cond_uscm            datetime  Real_Time  Temp_C  Cond_uScm-1  CellVoltage  \
# 0          0 2026-07-22 13:43:30  946685302   22.65            0         0.05
# 1          0 2026-07-22 13:43:50  946685323   23.06            0         0.05
# 2          0 2026-07-22 13:44:10  946685343   23.08            0         0.05
# 3          0 2026-07-22 13:44:30  946685363   23.10            0         0.05
# 4          0 2026-07-22 13:44:50  946685382   23.13            0         0.05
#
#    StateofCharge  ErrorCode  Elapsed_sec
# 0          62.53          0          497
# 1          61.06          0          518
# 2          59.79          0          538
# 3          58.53          0          558
# 4          56.95          0          577

# %%
plt.rcParams.update({'font.size': 22})
fig, axs = plt.subplots(figsize = (14, 10))

axs.scatter(mergedcleaned["Cond_uScm-1"], mergedcleaned["cond_uscm"], color = "red")
axs.set_ylabel('Set point (us/cm)')
axs.set_xlabel('C3PO Reading (us/cm)')

fig_fn = 'versusSetPoint'
fig_file = os.path.join(device, folder, 'Figures', device+fig_fn+'.png')
plt.savefig(fig_file, dpi = 200, transparent=False)

# %%
y = mergedcleaned["cond_uscm"]
x = mergedcleaned["Cond_uScm-1"] 

coef = np.polyfit(x,y,1)
print(coef)
poly1d_fn = np.poly1d(coef) 
y_predicted = poly1d_fn(x)
r_squared = r2_score(y, y_predicted)
print(f"R² Value: {r_squared:.4f}")
# Out:
# [   1.02507152 -668.01395061]
# R² Value: 0.9997

# %%
plt.rcParams.update({'font.size': 22})
fig, axs = plt.subplots(figsize = (14, 10))

m = coef[0]
b = coef[1]

axs.set_ylabel('Set point (us/cm)')
axs.set_xlabel('C3PO Reading (us/cm)')
axs.plot(x,y, 'ro', x, poly1d_fn(x), '--k', label=f'$y = {m:.1f}x {b:+.1f}$') 

plt.legend()
plt.text(0, 60000, f"R² Value: {r_squared:.4f}")


fig_fn = 'vsSetPoint_withRegression'
fig_file = os.path.join(device, folder, 'Figures', device+fig_fn+'.png')
plt.savefig(fig_file, dpi = 200, transparent=False)

# %%
plt.rcParams.update({'font.size': 22})
fig, axs = plt.subplots(figsize = (14, 10))

axs.plot(mergedcleaned["datetime"], mergedcleaned["Cond_uScm-1"], label = "C3PO reading pre-calibration", color = "red")
axs.plot(mergedcleaned["datetime"], m*mergedcleaned["Cond_uScm-1"] + b, label = "C3PO reading post-calibration", color = "blue")
axs.plot(mergedcleaned["datetime"], mergedcleaned["cond_uscm"] , label = "Set point", linestyle = '--', color = 'black')
axs.set_ylabel('Conductivity (us/cm)')
axs.set_xlabel('Datetime')

plt.legend()

fig_fn = 'PreandPostCalibration'
fig_file = os.path.join(device, folder, 'Figures', device+fig_fn+'.png')
plt.savefig(fig_file, dpi = 200, transparent=False)
