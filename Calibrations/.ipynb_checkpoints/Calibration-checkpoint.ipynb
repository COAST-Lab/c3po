# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import os
import scipy
import matplotlib.cm as cm
from datetime import datetime
import seaborn as sns
import pytz
import matplotlib
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from sklearn import metrics

# %%
filename = 'conductivity' #data from the calibration 
device = 'C3PO_1' 
filepath = os.path.join(device, filename+'.csv') 
cond = pd.read_csv(filepath, header = 0, parse_dates =[3], date_format='%yyyy-%m-%d %HH:%MM:%SS') 
cond.head()
cond.tail()
# Out:
#     Real_Time  Temp_C  Cond_uScm-1 Elapsed_sec            datetime
# 74  946686343   21.53        99290        1538  2025-4-23 12:58:00
# 75  946686363   21.53        99310        1558  2025-4-23 12:58:20
# 76  946686383   21.52        99260        1578  2025-4-23 12:58:40
# 77  946686403   21.52        99300        1598  2025-4-23 12:59:00
# 78  946686423   21.51        99260        1618  2025-4-23 12:59:20

# %%
filename = 'step_pts' #data from the calibration 
filepath = os.path.join(device, filename+'.txt') 
steps = pd.read_csv(filepath, header = 0, parse_dates =['datetime'], date_format='%yyyy-%m-%d %HH:%MM:%SS') 
steps.head()
# Out:
#    cond_uscm             datetime
# 0          0  2025-04-23 12:34:40
# 1          0  2025-04-23 12:41:52
# 2      12880  2025-04-23 12:41:53
# 3      12880  2025-04-23 12:51:30
# 4      80000  2025-04-23 12:51:31

# %%
cond['datetime'] = pd.to_datetime(cond['datetime'])
steps['datetime']= pd.to_datetime(steps['datetime'])

# %%
plt.rcParams.update({'font.size': 22})
fig, axs = plt.subplots(figsize = (14, 10))

axs.plot(cond["datetime"], cond["Cond_uScm-1"], label = "C3PO reading", color = "red")
axs.plot(steps["datetime"], steps["cond_uscm"], label = "Set point", marker = '*', color = "blue")
axs.set_ylabel('Conductivity (us/cm)')
axs.set_xlabel('Datetime')

plt.legend()

fig_fn = 'C3PO_1_RawReadings'
fig_file = os.path.join('C3PO_1\\Figures', fig_fn+'.png')
plt.savefig(fig_file, dpi = 200, transparent=False)

# %%
filename = 'step_pts_interp' #data from the calibration 
filepath = os.path.join(device, filename+'.csv') 
steps2 = pd.read_csv(filepath, header = 0, parse_dates =['datetime'], date_format='%yyyy-%m-%d %HH:%MM:%SS') 
steps2['datetime']= pd.to_datetime(steps2['datetime'])
steps2.head()
# Out:
#    cond_uscm            datetime
# 0          0 2025-04-23 12:34:40
# 1          0 2025-04-23 12:35:00
# 2          0 2025-04-23 12:35:20
# 3          0 2025-04-23 12:35:40
# 4          0 2025-04-23 12:36:00

# %%
merged = pd.merge_asof(steps2, cond, on='datetime', direction='nearest')
merged.to_csv('merged.csv', index=False)
print(merged)
# Out:
#     cond_uscm            datetime  Real_Time  Temp_C  Cond_uScm-1 Elapsed_sec
# 0           0 2025-04-23 12:34:40  946684942   21.95            0         137
# 1           0 2025-04-23 12:35:00  946684962   23.34            0         157
# 2           0 2025-04-23 12:35:20  946684982   23.65            0         177
# 3           0 2025-04-23 12:35:40  946685002   23.66            0         197
# 4           0 2025-04-23 12:36:00  946685022   23.67            0         217
# ..        ...                 ...        ...     ...          ...         ...
# 74      80000 2025-04-23 12:58:31  946686383   21.52        99260        1578
# 75      80000 2025-04-23 12:58:51  946686403   21.52        99300        1598
# 76      80000 2025-04-23 12:59:11  946686423   21.51        99260        1618
# 77      80000 2025-04-23 12:59:31  946686423   21.51        99260        1618
# 78      80000 2025-04-23 12:59:40  946686423   21.51        99260        1618
#
# [79 rows x 6 columns]

# %%
filename = 'merged' #data from the calibration 
filepath = os.path.join(device, filename+'.csv') 
mergedcleaned = pd.read_csv(filepath, header = 0, parse_dates =['datetime'], date_format='%yyyy-%m-%d %HH:%MM:%SS') 
mergedcleaned['datetime']= pd.to_datetime(mergedcleaned['datetime'])
mergedcleaned.head()
# Out:
#    cond_uscm            datetime  Real_Time  Temp_C  Cond_uScm-1  Elapsed_sec
# 0          0 2025-04-23 12:34:00  946684942   21.95            0          137
# 1          0 2025-04-23 12:35:00  946684962   23.34            0          157
# 2          0 2025-04-23 12:35:00  946684982   23.65            0          177
# 3          0 2025-04-23 12:35:00  946685002   23.66            0          197
# 4          0 2025-04-23 12:36:00  946685022   23.67            0          217

# %%
plt.rcParams.update({'font.size': 22})
fig, axs = plt.subplots(figsize = (14, 10))

axs.scatter(mergedcleaned["Cond_uScm-1"], mergedcleaned["cond_uscm"], color = "red")
axs.set_ylabel('Set point (us/cm)')
axs.set_xlabel('C3PO Reading (us/cm)')

fig_fn = 'SetPointvsC3POReading'
fig_file = os.path.join('C3PO_1\\Figures', fig_fn+'.png')
plt.savefig(fig_file, dpi = 200, transparent=False)

# %%
y = mergedcleaned["cond_uscm"]
x = mergedcleaned["Cond_uScm-1"] 

coef = np.polyfit(x,y,1)
print(coef)
poly1d_fn = np.poly1d(coef)
# Out:
# [  0.80364139 261.99225041]

# %%
plt.rcParams.update({'font.size': 22})
fig, axs = plt.subplots(figsize = (14, 10))

m = coef[0]
b = coef[1]

axs.set_ylabel('Set point (us/cm)')
axs.set_xlabel('C3PO Reading (us/cm)')
axs.plot(x,y, 'ro', x, poly1d_fn(x), '--k', label=f'$y = {m:.1f}x {b:+.1f}$') 

plt.legend()


fig_fn = 'SetPointvsC3POReading_withRegression'
fig_file = os.path.join('C3PO_1\\Figures', fig_fn+'.png')
plt.savefig(fig_file, dpi = 200, transparent=False)

# %%
plt.rcParams.update({'font.size': 22})
fig, axs = plt.subplots(figsize = (14, 10))

axs.plot(mergedcleaned["datetime"], mergedcleaned["Cond_uScm-1"], label = "C3PO reading pre-calibration", color = "red")
axs.plot(mergedcleaned["datetime"], 0.8*mergedcleaned["Cond_uScm-1"] + 262, label = "C3PO reading post-calibration", color = "blue")
axs.plot(mergedcleaned["datetime"], mergedcleaned["cond_uscm"] , label = "Set point", linestyle = '--', color = 'black')
axs.set_ylabel('Conductivity (us/cm)')
axs.set_xlabel('Datetime')

plt.legend()

fig_fn = 'PreandPostCalibration'
fig_file = os.path.join('C3PO_1\\Figures', fig_fn+'.png')
plt.savefig(fig_file, dpi = 200, transparent=False)
